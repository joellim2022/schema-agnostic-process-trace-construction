# %%
# !pip install keras-tcn --no-dependencies 
# !pip install tensorflow
# !pip install keras

# %%
# import key libraries to generate TCN
from tensorflow.keras import Sequential
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.datasets import imdb
from tensorflow.keras.layers import Dense, Dropout, Embedding
from tensorflow.keras.preprocessing import sequence
import random

import pandas as pd
import numpy as np
import random

import ast
import matplotlib as plt
import time

from tcn import TCN

random.seed(42)
# Out:
# 2025-11-27 16:00:01.711647: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-27 16:00:01.714063: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-27 16:00:01.771114: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-27 16:00:01.772257: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-27 16:00:02.724487: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# importing data
df               = pd.read_csv(f'data/input_sequences_i.csv', index_col=0)
df['Flow']       = df['Sequence'].apply(ast.literal_eval)

flow_context       = df[['Flow', 'Context']]
lists_with_context = [(row['Flow'], row['Context']) for _, row in flow_context.iterrows()]

# %%
df['Flow'].iloc[20]
# Out:
# ['EDM_DB.DBO.T_EXCEPTION_PRC',
#  'EDM_DB.DBO.T_PREMASTER_PRC',
#  'EDM_DB.DBO.T_OVERRIDE_SEC_DERIV_FI',
#  'EDM_DB.DBO.T_OVERRIDE_APPROVE_SEC_IDENTIFIER',
#  'EDM_DB.DBO.T_FULL_SEC_OUT_STORE',
#  'EDM_DB.DBO.T_BPS_PRC',
#  'EDM_DB.DBO.T_OVERRIDE_APPROVE_SEC',
#  'EDM_DB.DBO.T_MASTER_SEC_IDENTIFIER',
#  'EDM_DB.DBO.T_PK_OVERRIDE_SEC',
#  'EDM_DB.DBO.TMP_T_OVERRIDE_SEC_DERIV_FI',
#  'EDM_DB.DBO.BCK_T_OVERRIDE_SEC_DERIV_FI_20221201',
#  'EDM_DB.DBO.T_MASTER_PRC',
#  'EDM_DB.DBO.T_MASTER_SEC_BCK23092022',
#  'EDM_DB.DBO.T_OVERRIDE_PRC',
#  'EDM_DB.DBO.T_OVERRIDE_APPROVE_SEC_DERIV_FI',
#  'EDM_DB.DBO.T_MASTER_SEC',
#  'EDM_DB.DBO.T_EXCEPTION_SEC',
#  'EDM_DB.DBO.BCK_T_OVERRIDE_APPROVE_SEC_DERIV_FI_20221201',
#  'EDM_DB.DBO.T_MASTER_PRC_AUDIT']

# %%
# Tokenization of data values
tokenize_dict         = {'pad': 0, 
                         'eos': 1}

reverse_tokenize_dict = {0: 'pad', 
                         1: 'eos'}

max_len       = 0

for flow, context in lists_with_context:
    
    if context not in tokenize_dict.keys():
        tokenize_dict[context] = len(tokenize_dict)
        reverse_tokenize_dict[len(reverse_tokenize_dict)] = context
        
        
    for element in flow:
        if (element, context) not in tokenize_dict.keys():
            tokenize_dict[(element, context)] = len(tokenize_dict)
            reverse_tokenize_dict[len(reverse_tokenize_dict)] = (element, context)
    
    if len(flow) > max_len:
        max_len = len(flow)

feature_length = len(tokenize_dict)
print(feature_length, max_len)

# To numerical and N-gram
context_window      = 8
numerical_sequences = []
input_sequences     = []

for flow, context in lists_with_context:
    
    seq = [tokenize_dict[context]]
    for element in flow: 
        seq.append(tokenize_dict[(element, context)])
    
    seq.append(tokenize_dict['eos'])
    numerical_sequences.append(seq)
# Out:
# 170 37

# %%
for line in numerical_sequences:
    # Introduce padding
    newline = (context_window-2)*[0] + line
    
    for i in range(context_window, len(newline)):
        n_gram_sequence = newline[i-context_window:i]
        if len(n_gram_sequence) == context_window:
            input_sequences.append(n_gram_sequence)

# %%
# Padding to ensure sequences are equal length
X                   = np.array([seq[:-1] for seq in input_sequences])
y                   = np.array([seq[-1] for seq in input_sequences])

msk                 = np.random.rand(len(X)) < 0.8

# Generate training and validation data
X_train, y_train    = X[msk], y[msk]
X_test, y_test      = X[~msk], y[~msk]

# %%
# TCN parameters
n_epochs       = 10
batch_size     = 4
embedding_size = 16

# Generate TCN architecture and model
tcn = TCN(
        nb_filters=8,
        kernel_size=2,
        dilations=(1, 2, 4),
        use_skip_connections=True,
        use_layer_norm=True
)

model = Sequential(layers=[
    Embedding(feature_length, embedding_size, mask_zero=True),
    Dropout(rate=0.3),
    tcn,
    Dense(feature_length, activation='softmax')
])

# %%
# Compile and train mode
model.summary()
model.compile('adam', 'sparse_categorical_crossentropy', metrics=['accuracy'])
r = model.fit(
    X_train, y_train,
    batch_size=batch_size,
    validation_data=(X_test, y_test),
    epochs=n_epochs
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 16)          2720
#
#  dropout (Dropout)           (None, None, 16)          0
#
#  tcn_1 (TCN)                 (None, 8)                 1176
#
#  dense (Dense)               (None, 170)               1530
#
# =================================================================
# Total params: 5426 (21.20 KB)
# Trainable params: 5426 (21.20 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 10212/10212 [==============================] - 63s 6ms/step - loss: 2.0358 - accuracy: 0.5193 - val_loss: 0.9253 - val_accuracy: 0.7354
# Epoch 2/10
# 10212/10212 [==============================] - 55s 5ms/step - loss: 0.9298 - accuracy: 0.7193 - val_loss: 0.7376 - val_accuracy: 0.7572
# Epoch 3/10
# 10212/10212 [==============================] - 58s 6ms/step - loss: 0.8077 - accuracy: 0.7376 - val_loss: 0.6695 - val_accuracy: 0.7830
# Epoch 4/10
# 10212/10212 [==============================] - 63s 6ms/step - loss: 0.7503 - accuracy: 0.7519 - val_loss: 0.6483 - val_accuracy: 0.7828
# Epoch 5/10
# 10212/10212 [==============================] - 63s 6ms/step - loss: 0.7095 - accuracy: 0.7627 - val_loss: 0.5954 - val_accuracy: 0.7979
# Epoch 6/10
# 10212/10212 [==============================] - 63s 6ms/step - loss: 0.6883 - accuracy: 0.7673 - val_loss: 0.5779 - val_accuracy: 0.7943
# Epoch 7/10
# 10212/10212 [==============================] - 63s 6ms/step - loss: 0.6652 - accuracy: 0.7747 - val_loss: 0.5625 - val_accuracy: 0.8090
# Epoch 8/10
# 10212/10212 [==============================] - 61s 6ms/step - loss: 0.6522 - accuracy: 0.7759 - val_loss: 0.5636 - val_accuracy: 0.8065
# Epoch 9/10
# 10212/10212 [==============================] - 63s 6ms/step - loss: 0.6354 - accuracy: 0.7826 - val_loss: 0.5456 - val_accuracy: 0.8178
# Epoch 10/10
# 10212/10212 [==============================] - 63s 6ms/step - loss: 0.6205 - accuracy: 0.7863 - val_loss: 0.5305 - val_accuracy: 0.8170

# %%
# Predict best sequence based on earlier sequences
def pre_padding(context, tokenizer=tokenize_dict, context_window=context_window):
    # Conducts pre-padding on context
    context_values = [tokenizer[c] for c in context]
    padded_context = np.array([0] * (context_window - len(context_values) - 1) + context_values)
    
    return padded_context.reshape((1, len(padded_context)))

def process_identification(padded_context,
                           reverse_tokenizer=reverse_tokenize_dict, 
                           model=model):
    # Conducts pre-padding on context
    # Iteratively find the most probable next step based on model
    context_value   = padded_context[:, -1][0]
    context         = reverse_tokenizer[context_value]
    processes       = [k for k, v in reverse_tokenizer.items() if (context in v) & (k != context_value)]
    
    process_vlist   = [context_value]
    process_klist   = [context]

    while len(processes) > 0:
        maxv, maxp      = 0, None
        
        preds           = model.predict(padded_context)[0]

        for process in processes:
            if preds[process] >= maxv:
                maxv = preds[process]
                maxp = process
        
        # Remove models selected before (no cycles)
        processes.remove(maxp)
        process_vlist.append(maxp)
        process_klist.append(reverse_tokenizer[maxp])
        
        padded_context = pre_padding(process_klist)
        
    return [reverse_tokenizer[c] for c in padded_context[0] if c > 0][1:]

# %%
import matplotlib.pyplot as plt

# Plot model accuracy and loss across epochs
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.plot(r.history['accuracy'])
plt.plot(r.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(122)
plt.plot(r.history['loss'])
plt.plot(r.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
plt.show()

# %%
df.iloc[20]
# Out:
# Sequence    ['EDM_DB.DBO.T_EXCEPTION_PRC', 'EDM_DB.DBO.T_P...
# Context                                      Zero Price Value
# Flow        [EDM_DB.DBO.T_EXCEPTION_PRC, EDM_DB.DBO.T_PREM...
# Name: 434282, dtype: object

# %%
pre_padding(['Zero Price Value', ('EDM_DB.DBO.T_EXCEPTION_PRC', 'Zero Price Value')]
# Out:
# array([[ 0,  0,  0,  0,  0, 67, 68]])
